# %% [markdown]
# # Loading and filtering features from Single cell dataset

# %%
import pandas as pd        
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
path_data = "/shared/projects/microbiome_translocation/data/Tabula_sapiens_immune_all/"


adata = sc.read(path_data + "immune_all_cell.h5ad")

# %%
blood_adata = adata[adata.obs.tissue_in_publication.isin(["Blood"]),:]

df = blood_adata.to_df()

# Renaming genes and cell id
gene_name = np.asarray(blood_adata.var.feature_name).tolist()
gene_id = np.asarray(blood_adata.var.index).tolist()
ID = blood_adata.obs.index.tolist()
types = np.asarray(blood_adata.obs.cell_type).tolist()

df = df.rename(columns=dict(zip(gene_id,gene_name)),index=dict(zip(ID,types)))
df
# Out:
# ensemblid                                           DDX11L1   WASH7P  \
# erythrocyte                                             0.0  0.00000
# erythrocyte                                             0.0  0.00000
# CD4-positive, alpha-beta memory T cell                  0.0  0.00000
# CD8-positive, alpha-beta cytokine secreting eff...      0.0  0.00000
# classical monocyte                                      0.0  0.00000
# ...                                                     ...      ...
# CD4-positive, alpha-beta T cell                         0.0  0.00000
# CD4-positive, alpha-beta T cell                         0.0  0.00000
# CD4-positive, alpha-beta T cell                         0.0  0.00000
# CD4-positive, alpha-beta T cell                         0.0  0.00000
# naive B cell                                            0.0  4.93698
#
# ensemblid                                           MIR6859-1  MIR1302-2HG  \
# erythrocyte                                               0.0          0.0
# erythrocyte                                               0.0          0.0
# CD4-positive, alpha-beta memory T cell                    0.0          0.0
# CD8-positive, alpha-beta cytokine secreting eff...        0.0          0.0
# classical monocyte                                        0.0          0.0
# ...                                                       ...          ...
# CD4-positive, alpha-beta T cell                           0.0          0.0
# CD4-positive, alpha-beta T cell                           0.0          0.0
# CD4-positive, alpha-beta T cell                           0.0          0.0
# CD4-positive, alpha-beta T cell                           0.0          0.0
# naive B cell                                              0.0          0.0
#
# ensemblid                                           MIR1302-2  FAM138A  \
# erythrocyte                                               0.0      0.0
# erythrocyte                                               0.0      0.0
# CD4-positive, alpha-beta memory T cell                    0.0      0.0
# CD8-positive, alpha-beta cytokine secreting eff...        0.0      0.0
# classical monocyte                                        0.0      0.0
# ...                                                       ...      ...
# CD4-positive, alpha-beta T cell                           0.0      0.0
# CD4-positive, alpha-beta T cell                           0.0      0.0
# CD4-positive, alpha-beta T cell                           0.0      0.0
# CD4-positive, alpha-beta T cell                           0.0      0.0
# naive B cell                                              0.0      0.0
#
# ensemblid                                           OR4G4P  OR4G11P  OR4F5  \
# erythrocyte                                            0.0      0.0    0.0
# erythrocyte                                            0.0      0.0    0.0
# CD4-positive, alpha-beta memory T cell                 0.0      0.0    0.0
# CD8-positive, alpha-beta cytokine secreting eff...     0.0      0.0    0.0
# classical monocyte                                     0.0      0.0    0.0
# ...                                                    ...      ...    ...
# CD4-positive, alpha-beta T cell                        0.0      0.0    0.0
# CD4-positive, alpha-beta T cell                        0.0      0.0    0.0
# CD4-positive, alpha-beta T cell                        0.0      0.0    0.0
# CD4-positive, alpha-beta T cell                        0.0      0.0    0.0
# naive B cell                                           0.0      0.0    0.0
#
# ensemblid                                           RP11-34P13.7  ...  \
# erythrocyte                                                  0.0  ...
# erythrocyte                                                  0.0  ...
# CD4-positive, alpha-beta memory T cell                       0.0  ...
# CD8-positive, alpha-beta cytokine secreting eff...           0.0  ...
# classical monocyte                                           0.0  ...
# ...                                                          ...  ...
# CD4-positive, alpha-beta T cell                              0.0  ...
# CD4-positive, alpha-beta T cell                              0.0  ...
# CD4-positive, alpha-beta T cell                              0.0  ...
# CD4-positive, alpha-beta T cell                              0.0  ...
# naive B cell                                                 0.0  ...
#
# ensemblid                                             MT-ND4  MT-TH  MT-TS2  \
# erythrocyte                                         2.396265    0.0     0.0
# erythrocyte                                         0.500448    0.0     0.0
# CD4-positive, alpha-beta memory T cell              3.300591    0.0     0.0
# CD8-positive, alpha-beta cytokine secreting eff...  3.610880    0.0     0.0
# classical monocyte                                  3.128788    0.0     0.0
# ...                                                      ...    ...     ...
# CD4-positive, alpha-beta T cell                     2.468975    0.0     0.0
# CD4-positive, alpha-beta T cell                     2.049129    0.0     0.0
# CD4-positive, alpha-beta T cell                     3.143907    0.0     0.0
# CD4-positive, alpha-beta T cell                     1.991743    0.0     0.0
# naive B cell                                        0.000000    0.0     0.0
#
# ensemblid                                           MT-TL2    MT-ND5  \
# erythrocyte                                            0.0  0.000000
# erythrocyte                                            0.0  0.558787
# CD4-positive, alpha-beta memory T cell                 0.0  3.070026
# CD8-positive, alpha-beta cytokine secreting eff...     0.0  3.174738
# classical monocyte                                     0.0  2.992075
# ...                                                    ...       ...
# CD4-positive, alpha-beta T cell                        0.0  2.999030
# CD4-positive, alpha-beta T cell                        0.0  1.941740
# CD4-positive, alpha-beta T cell                        0.0  2.293076
# CD4-positive, alpha-beta T cell                        0.0  3.062743
# naive B cell                                           0.0  2.643178
#
# ensemblid                                             MT-ND6  MT-TE    MT-CYB  \
# erythrocyte                                         1.518963    0.0  1.794237
# erythrocyte                                         0.000000    0.0  0.847475
# CD4-positive, alpha-beta memory T cell              0.000000    0.0  3.761100
# CD8-positive, alpha-beta cytokine secreting eff...  2.748144    0.0  4.052015
# classical monocyte                                  0.000000    0.0  3.277448
# ...                                                      ...    ...       ...
# CD4-positive, alpha-beta T cell                     0.000000    0.0  1.174247
# CD4-positive, alpha-beta T cell                     1.271020    0.0  3.194520
# CD4-positive, alpha-beta T cell                     0.000000    0.0  3.186714
# CD4-positive, alpha-beta T cell                     2.814439    0.0  4.208903
# naive B cell                                        1.419954    0.0  2.382827
#
# ensemblid                                           MT-TT     MT-TP
# erythrocyte                                           0.0  0.000000
# erythrocyte                                           0.0  0.000000
# CD4-positive, alpha-beta memory T cell                0.0  0.000000
# CD8-positive, alpha-beta cytokine secreting eff...    0.0  1.957541
# classical monocyte                                    0.0  0.000000
# ...                                                   ...       ...
# CD4-positive, alpha-beta T cell                       0.0  0.000000
# CD4-positive, alpha-beta T cell                       0.0  0.000000
# CD4-positive, alpha-beta T cell                       0.0  7.515769
# CD4-positive, alpha-beta T cell                       0.0  7.788391
# naive B cell                                          0.0  0.000000
#
# [50115 rows x 58604 columns]

# %%
len(df.columns)
# Out:
# 58604

# %%
len(df.index)
# Out:
# 50115

# %% [markdown]
# **58604 features and 50115 cells**

# %%
from collections import Counter

Counter(df.index)
# Out:
# Counter({'erythrocyte': 10484,
#          'CD4-positive, alpha-beta memory T cell': 949,
#          'CD8-positive, alpha-beta cytokine secreting effector T cell': 1493,
#          'classical monocyte': 7211,
#          'neutrophil': 8456,
#          'naive B cell': 2239,
#          'mature NK T cell': 2948,
#          'memory B cell': 854,
#          'type I NK T cell': 518,
#          'CD141-positive myeloid dendritic cell': 15,
#          'CD8-positive, alpha-beta T cell': 1322,
#          'plasma cell': 488,
#          'T cell': 31,
#          'platelet': 239,
#          'naive thymus-derived CD4-positive, alpha-beta T cell': 412,
#          'non-classical monocyte': 8,
#          'hematopoietic stem cell': 70,
#          'plasmacytoid dendritic cell': 11,
#          'basophil': 29,
#          'CD4-positive, alpha-beta T cell': 2863,
#          'monocyte': 8972,
#          'plasmablast': 10,
#          'common myeloid progenitor': 3,
#          'macrophage': 488,
#          'granulocyte': 2})

# %%
df_no_zero = df.loc[:, (df.sum(axis=0) > 0)]
len(df_no_zero.columns)
# Out:
# 52220

# %% [markdown]
# **52220 features with at least one cell expressing the corresponding gene**

# %%
df_no_zero.to_csv(path_data+"50000cell_immune_expressed.csv", sep='\t')

# %%
file = open(path_data+'50k_cell_labels.txt','w')
for cells in df.index.to_list():
	file.write(cells+"\n")
file.close()données

file = open(path_data+'50k_cells_geneset/50k_cell_genes.txt','w')
for cells in mat.columns.to_list():
	file.write(cells+"\n")
file.close()
